# %%
import pandas as pd

# Load the datasets
a="E:/DA_Projects/2/Customers.csv"
b="E:/DA_Projects/2/Products.csv"
c="E:/DA_Projects/2/Transactions.csv"
customers = pd.read_csv(a)
products = pd.read_csv(b)
transactions = pd.read_csv(c)

print(customers.head())
print(products.head())
print(transactions.head())
# Out:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15
#   ProductID              ProductName     Category   Price
# 0      P001     ActiveWear Biography        Books  169.30
# 1      P002    ActiveWear Smartwatch  Electronics  346.30
# 2      P003  ComfortLiving Biography        Books   44.12
# 3      P004            BookWorld Rug   Home Decor   95.69
# 4      P005          TechPro T-Shirt     Clothing  429.31
#   TransactionID CustomerID ProductID TransactionDate  Quantity  TotalValue  \
# 0        T00001      C0199      P067      25-08-2024         1      300.68
# 1        T00112      C0146      P067      27-05-2024         1      300.68
# 2        T00166      C0127      P067      25-04-2024         1      300.68
# 3        T00272      C0087      P067      26-03-2024         2      601.36
# 4        T00363      C0070      P067      21-03-2024         3      902.04
#
#     Price
# 0  300.68
# 1  300.68
# 2  300.68
# 3  300.68
# 4  300.68

# %%
import pandas as pd

file_path = a
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    200 non-null    object
#  1   CustomerName  200 non-null    object
#  2   Region        200 non-null    object
#  3   SignupDate    200 non-null    object
# dtypes: object(4)
# memory usage: 6.4+ KB
# None

# %%
import pandas as pd

file_path = b
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    100 non-null    object
#  1   ProductName  100 non-null    object
#  2   Category     100 non-null    object
#  3   Price        100 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB
# None

# %%
import pandas as pd

file_path = c
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price            1000 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 54.8+ KB
# None

# %%
import pandas as pd
file_path = a
df = pd.read_csv(file_path)
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)

if null_values.any():
    print("\nThere are null values in the dataset.")
else:
    print("\nNo null values found in the dataset.")
# Out:
# Null values in each column:
# CustomerID      0
# CustomerName    0
# Region          0
# SignupDate      0
# dtype: int64
#
# No null values found in the dataset.

# %%
import pandas as pd
file_path = b
df = pd.read_csv(file_path)
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)

if null_values.any():
    print("\nThere are null values in the dataset.")
else:
    print("\nNo null values found in the dataset.")
# Out:
# Null values in each column:
# ProductID      0
# ProductName    0
# Category       0
# Price          0
# dtype: int64
#
# No null values found in the dataset.

# %%
import pandas as pd
file_path = c
df = pd.read_csv(file_path)
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)

if null_values.any():
    print("\nThere are null values in the dataset.")
else:
    print("\nNo null values found in the dataset.")
# Out:
# Null values in each column:
# TransactionID      0
# CustomerID         0
# ProductID          0
# TransactionDate    0
# Quantity           0
# TotalValue         0
# Price              0
# dtype: int64
#
# No null values found in the dataset.

# %%
import pandas as pd
file_path = a
df = pd.read_csv(file_path)
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
if duplicates > 0:
    print("\nDuplicate rows:")
    print(df[df.duplicated()])
else:
    print("\nNo duplicate rows found.")
# Out:
# Number of duplicate rows: 0
#
# No duplicate rows found.

# %%
import pandas as pd
file_path = b
df = pd.read_csv(file_path)
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
if duplicates > 0:
    print("\nDuplicate rows:")
    print(df[df.duplicated()])
else:
    print("\nNo duplicate rows found.")
# Out:
# Number of duplicate rows: 0
#
# No duplicate rows found.

# %%
import pandas as pd
file_path = c
df = pd.read_csv(file_path)
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
if duplicates > 0:
    print("\nDuplicate rows:")
    print(df[df.duplicated()])
else:
    print("\nNo duplicate rows found.")
# Out:
# Number of duplicate rows: 0
#
# No duplicate rows found.

# %%
import pandas as pd

def find_duplicates_in_csv(file_path, columns=None):
  df = pd.read_csv(file_path)
  if columns:
    duplicates = df[df.duplicated(subset=columns, keep=False)] 
  else:
    duplicates = df[df.duplicated(keep=False)] 
  return duplicates

# Example usage:
file_path = a 
# Specify columns to check for duplicates (optional)
columns_to_check = ["CustomerID", "CustomerName","Region","SignupDate"] 

duplicate_rows = find_duplicates_in_csv(file_path, columns=columns_to_check)

if not duplicate_rows.empty:
  print("Duplicate rows found:")
  print(duplicate_rows)
else:
  print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
import pandas as pd

def find_duplicates_in_csv(file_path, columns=None):
  df = pd.read_csv(file_path)
  if columns:
    duplicates = df[df.duplicated(subset=columns, keep=False)] 
  else:
    duplicates = df[df.duplicated(keep=False)] 
  return duplicates

# Example usage:
file_path = b
# Specify columns to check for duplicates (optional)
columns_to_check = ["ProductID", "ProductName","Category","Price"] 

duplicate_rows = find_duplicates_in_csv(file_path, columns=columns_to_check)

if not duplicate_rows.empty:
  print("Duplicate rows found:")
  print(duplicate_rows)
else:
  print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
import pandas as pd

def find_duplicates_in_csv(file_path, columns=None):
  df = pd.read_csv(file_path)
  if columns:
    duplicates = df[df.duplicated(subset=columns, keep=False)] 
  else:
    duplicates = df[df.duplicated(keep=False)] 
  return duplicates

file_path = c
columns_to_check = ["TransactionID","CustomerID","ProductID","TransactionDate","Quantity","TotalValue","Price"] 

duplicate_rows = find_duplicates_in_csv(file_path, columns=columns_to_check)

if not duplicate_rows.empty:
  print("Duplicate rows found:")
  print(duplicate_rows)
else:
  print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
import pandas as pd

def find_outliers_iqr_multiple_columns(df, columns):
  outliers_dict = {}
  for column in columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)].index.tolist()
    outliers_dict[column] = outliers
  return outliers_dict

# Example usage:
file_path = c
df = pd.read_csv(file_path)

columns_to_check = ["Quantity","TotalValue","Price"]
outliers = find_outliers_iqr_multiple_columns(df, columns_to_check)

for column, indices in outliers.items():
  if indices:
    print(f"Outliers found in '{column}':")
    print(df.loc[indices, [column]])  # Print only the outlier values for the specific column
  else:
    print(f"No outliers found in '{column}'.")
# Out:
# No outliers found in 'Quantity'.
# No outliers found in 'TotalValue'.
# No outliers found in 'Price'.

# %%
"""Mergeing the data of consumer and product to transcation dat based on 
ProductID and CustomerID"""
import pandas as pd
transactions = pd.read_csv(c)
customers = pd.read_csv(a)
merged_df = pd.merge(transactions, customers, on="CustomerID", how="left")
print(merged_df)
merged_df.to_csv("E:/DA_Projects/2/merged_data.csv", index=False)
# Out:
#     TransactionID CustomerID ProductID TransactionDate  Quantity  TotalValue  \
# 0          T00001      C0199      P067      25-08-2024         1      300.68
# 1          T00112      C0146      P067      27-05-2024         1      300.68
# 2          T00166      C0127      P067      25-04-2024         1      300.68
# 3          T00272      C0087      P067      26-03-2024         2      601.36
# 4          T00363      C0070      P067      21-03-2024         3      902.04
# ..            ...        ...       ...             ...       ...         ...
# 995        T00496      C0118      P037      24-10-2024         1      459.86
# 996        T00759      C0059      P037      04-06-2024         3     1379.58
# 997        T00922      C0018      P037      05-04-2024         4     1839.44
# 998        T00959      C0115      P037      29-09-2024         2      919.72
# 999        T00992      C0024      P037      21-04-2024         1      459.86
#
#       Price          CustomerName         Region  SignupDate
# 0    300.68        Andrea Jenkins         Europe  2022-12-03
# 1    300.68       Brittany Harvey           Asia  2024-09-04
# 2    300.68       Kathryn Stevens         Europe  2024-04-04
# 3    300.68       Travis Campbell  South America  2024-04-11
# 4    300.68         Timothy Perez         Europe  2022-03-15
# ..      ...                   ...            ...         ...
# 995  459.86            Jacob Holt  South America  2022-01-22
# 996  459.86  Mrs. Kimberly Wright  North America  2024-04-07
# 997  459.86          Tyler Haynes  North America  2024-09-21
# 998  459.86       Joshua Hamilton           Asia  2024-11-11
# 999  459.86        Michele Cooley  North America  2024-02-05
#
# [1000 rows x 10 columns]

# %%
import pandas as pd
transactions = pd.read_csv("E:/DA_Projects/2/merged_data.csv")
customers = pd.read_csv(b)
merged_df = pd.merge(transactions, customers, on="ProductID", how="left")
print(merged_df)
merged_df.to_csv("E:/DA_Projects/2/merged_data.csv", index=False)
# Out:
#     TransactionID CustomerID ProductID TransactionDate  Quantity  TotalValue  \
# 0          T00001      C0199      P067      25-08-2024         1      300.68
# 1          T00112      C0146      P067      27-05-2024         1      300.68
# 2          T00166      C0127      P067      25-04-2024         1      300.68
# 3          T00272      C0087      P067      26-03-2024         2      601.36
# 4          T00363      C0070      P067      21-03-2024         3      902.04
# ..            ...        ...       ...             ...       ...         ...
# 995        T00496      C0118      P037      24-10-2024         1      459.86
# 996        T00759      C0059      P037      04-06-2024         3     1379.58
# 997        T00922      C0018      P037      05-04-2024         4     1839.44
# 998        T00959      C0115      P037      29-09-2024         2      919.72
# 999        T00992      C0024      P037      21-04-2024         1      459.86
#
#      Price_x          CustomerName         Region  SignupDate  \
# 0     300.68        Andrea Jenkins         Europe  2022-12-03
# 1     300.68       Brittany Harvey           Asia  2024-09-04
# 2     300.68       Kathryn Stevens         Europe  2024-04-04
# 3     300.68       Travis Campbell  South America  2024-04-11
# 4     300.68         Timothy Perez         Europe  2022-03-15
# ..       ...                   ...            ...         ...
# 995   459.86            Jacob Holt  South America  2022-01-22
# 996   459.86  Mrs. Kimberly Wright  North America  2024-04-07
# 997   459.86          Tyler Haynes  North America  2024-09-21
# 998   459.86       Joshua Hamilton           Asia  2024-11-11
# 999   459.86        Michele Cooley  North America  2024-02-05
#
#                          ProductName     Category  Price_y
# 0    ComfortLiving Bluetooth Speaker  Electronics   300.68
# 1    ComfortLiving Bluetooth Speaker  Electronics   300.68
# 2    ComfortLiving Bluetooth Speaker  Electronics   300.68
# 3    ComfortLiving Bluetooth Speaker  Electronics   300.68
# 4    ComfortLiving Bluetooth Speaker  Electronics   300.68
# ..                               ...          ...      ...
# 995             SoundWave Smartwatch  Electronics   459.86
# 996             SoundWave Smartwatch  Electronics   459.86
# 997             SoundWave Smartwatch  Electronics   459.86
# 998             SoundWave Smartwatch  Electronics   459.86
# 999             SoundWave Smartwatch  Electronics   459.86
#
# [1000 rows x 13 columns]

# %%
d="E:/DA_Projects/2/merged_data.csv"

# %%
import pandas as pd

file_path = d
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price_x          1000 non-null   float64
#  7   CustomerName     1000 non-null   object
#  8   Region           1000 non-null   object
#  9   SignupDate       1000 non-null   object
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
#  12  Price_y          1000 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 101.7+ KB
# None

# %%
import pandas as pd
df = pd.read_csv(d)
df = df.drop('Price_y', axis=1)

# %%
import pandas as pd

file_path = d
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price_x          1000 non-null   float64
#  7   CustomerName     1000 non-null   object
#  8   Region           1000 non-null   object
#  9   SignupDate       1000 non-null   object
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB
# None

# %%
import pandas as pd

def analyze_column(file_path, column_name):
  try:
    df = pd.read_csv(file_path)
  except FileNotFoundError:
    print(f"Error: File not found: {file_path}")
    return None

  try:
    column_data = df[column_name]
  except KeyError:
    print(f"Error: Column '{column_name}' not found in the file.")
    return None

  # Handle potential missing values
  column_data = column_data.dropna() 

  stats = {
      'count': len(column_data),
      'mean': column_data.mean(),
      'std': column_data.std(),
      'min': column_data.min(),
      '25%': column_data.quantile(0.25),
      '50%': column_data.median(),
      '75%': column_data.quantile(0.75),
      'max': column_data.max()
  }

  return stats

# Example usage:
file_path = d  # Replace with the actual file path
column_name = 'Quantity'  # Replace with the actual column name

column_stats = analyze_column(file_path, column_name)

if column_stats:
  print(f"Statistical Analysis for '{column_name}':")
  for stat, value in column_stats.items():
    print(f"{stat}: {value}")
# Out:
# Statistical Analysis for 'Quantity':
# count: 1000
# mean: 2.537
# std: 1.117980715791143
# min: 1
# 25%: 2.0
# 50%: 3.0
# 75%: 4.0
# max: 4

# %%
import pandas as pd

def analyze_column(file_path, column_name):
  try:
    df = pd.read_csv(file_path)
  except FileNotFoundError:
    print(f"Error: File not found: {file_path}")
    return None

  try:
    column_data = df[column_name]
  except KeyError:
    print(f"Error: Column '{column_name}' not found in the file.")
    return None

  # Handle potential missing values
  column_data = column_data.dropna() 

  stats = {
      'count': len(column_data),
      'mean': column_data.mean(),
      'std': column_data.std(),
      'min': column_data.min(),
      '25%': column_data.quantile(0.25),
      '50%': column_data.median(),
      '75%': column_data.quantile(0.75),
      'max': column_data.max()
  }

  return stats

# Example usage:
file_path = d  # Replace with the actual file path
column_name = 'TotalValue'  # Replace with the actual column name

column_stats = analyze_column(file_path, column_name)

if column_stats:
  print(f"Statistical Analysis for '{column_name}':")
  for stat, value in column_stats.items():
    print(f"{stat}: {value}")
# Out:
# Statistical Analysis for 'TotalValue':
# count: 1000
# mean: 689.995559999999
# std: 493.14447754793144
# min: 16.08
# 25%: 295.29499999999996
# 50%: 588.88
# 75%: 1011.66
# max: 1991.04

# %%
import pandas as pd

def analyze_column(file_path, column_name):
  try:
    df = pd.read_csv(file_path)
  except FileNotFoundError:
    print(f"Error: File not found: {file_path}")
    return None

  try:
    column_data = df[column_name]
  except KeyError:
    print(f"Error: Column '{column_name}' not found in the file.")
    return None

  # Handle potential missing values
  column_data = column_data.dropna() 

  stats = {
      'count': len(column_data),
      'mean': column_data.mean(),
      'std': column_data.std(),
      'min': column_data.min(),
      '25%': column_data.quantile(0.25),
      '50%': column_data.median(),
      '75%': column_data.quantile(0.75),
      'max': column_data.max()
  }

  return stats

# Example usage:
file_path = d  # Replace with the actual file path
column_name = 'Price_x'  # Replace with the actual column name

column_stats = analyze_column(file_path, column_name)

if column_stats:
  print(f"Statistical Analysis for '{column_name}':")
  for stat, value in column_stats.items():
    print(f"{stat}: {value}")
# Out:
# Statistical Analysis for 'Price_x':
# count: 1000
# mean: 272.5540699999993
# std: 140.73638962578207
# min: 16.08
# 25%: 147.95
# 50%: 299.93
# 75%: 404.4
# max: 497.76

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data (replace 'your_data.csv' with the actual file path)
df = pd.read_csv(d)

# Convert 'TransactionDate' and 'SignupDate' to datetime format
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
df['SignupDate'] = pd.to_datetime(df['SignupDate'])
# Out:
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-09-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-10-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-09-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-06-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-09-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-08-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-04-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-03-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-02-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-11-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-07-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-07-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-10-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-03-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-02-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-11-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-11-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-11-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-12-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-02-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-10-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-07-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-06-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-10-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-09-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-04-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-09-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-09-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\mayan\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)

# %%
# 1. Quantity
print("\nQuantity Analysis:")
print(df['Quantity'].describe())
plt.figure(figsize=(8, 4))
sns.histplot(df['Quantity'], bins=20)
plt.title("Distribution of Quantity")
plt.show()
# Out:
# Quantity Analysis:
# count    1000.000000
# mean        2.537000
# std         1.117981
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: Quantity, dtype: float64

# %%
# 2. TotalValue
print("\nTotalValue Analysis:")
print(df['TotalValue'].describe())
plt.figure(figsize=(8, 4))
sns.histplot(df['TotalValue'], bins=20)
plt.title("Distribution of TotalValue")
plt.show()
# Out:
# TotalValue Analysis:
# count    1000.000000
# mean      689.995560
# std       493.144478
# min        16.080000
# 25%       295.295000
# 50%       588.880000
# 75%      1011.660000
# max      1991.040000
# Name: TotalValue, dtype: float64

# %%
# 3. Price_x
print("\nPrice_x Analysis:")
print(df['Price_x'].describe())
plt.figure(figsize=(8, 4))
sns.histplot(df['Price_x'], bins=20)
plt.title("Distribution of Price_x")
plt.show()
# Out:
# Price_x Analysis:
# count    1000.00000
# mean      272.55407
# std       140.73639
# min        16.08000
# 25%       147.95000
# 50%       299.93000
# 75%       404.40000
# max       497.76000
# Name: Price_x, dtype: float64

# %%
# 1. CustomerID
print("\nCustomerID Analysis:")
print(df['CustomerID'].nunique())  # Number of unique customers
print(df['CustomerID'].value_counts().head())  # Top 5 customers by transaction count
# Out:
# CustomerID Analysis:
# 199
# C0109    11
# C0156    11
# C0141    10
# C0175    10
# C0065    10
# Name: CustomerID, dtype: int64

# %%
# 2. ProductID
print("\nProductID Analysis:")
print(df['ProductID'].nunique())  # Number of unique products
print(df['ProductID'].value_counts().head())  # Top 5 products by transaction count
# Out:
# ProductID Analysis:
# 100
# P059    19
# P029    17
# P062    16
# P079    16
# P054    16
# Name: ProductID, dtype: int64

# %%
# 3. Region
print("\nRegion Analysis:")
print(df['Region'].value_counts())
plt.figure(figsize=(8, 4))
sns.countplot(x='Region', data=df)
plt.title("Distribution of Transactions by Region")
plt.show()
# Out:
# Region Analysis:
# South America    304
# North America    244
# Europe           234
# Asia             218
# Name: Region, dtype: int64

# %%
# 4. Category
print("\nCategory Analysis:")
print(df['Category'].value_counts())
plt.figure(figsize=(8, 4))
sns.countplot(x='Category', data=df)
plt.title("Distribution of Transactions by Category")
plt.show()
# Out:
# Category Analysis:
# Books          270
# Electronics    254
# Home Decor     248
# Clothing       228
# Name: Category, dtype: int64

# %%
# 1. Daily Transactions
daily_transactions = df.groupby(df['TransactionDate'].dt.date)['TransactionID'].count()
plt.figure(figsize=(12, 6))
plt.plot(daily_transactions.index, daily_transactions.values)
plt.xlabel('Date')
plt.ylabel('Number of Transactions')
plt.title('Daily Transactions')
plt.show()
