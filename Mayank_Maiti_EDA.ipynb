# %%
import pandas as pd

# Load the datasets
a="E:/DA_Projects/2/Customers.csv"
b="E:/DA_Projects/2/Products.csv"
c="E:/DA_Projects/2/Transactions.csv"
customers = pd.read_csv(a)
products = pd.read_csv(b)
transactions = pd.read_csv(c)

print(customers.head())
print(products.head())
print(transactions.head())
# Out:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15
#   ProductID              ProductName     Category   Price
# 0      P001     ActiveWear Biography        Books  169.30
# 1      P002    ActiveWear Smartwatch  Electronics  346.30
# 2      P003  ComfortLiving Biography        Books   44.12
# 3      P004            BookWorld Rug   Home Decor   95.69
# 4      P005          TechPro T-Shirt     Clothing  429.31
#   TransactionID CustomerID ProductID TransactionDate  Quantity  TotalValue  \
# 0        T00001      C0199      P067      25-08-2024         1      300.68
# 1        T00112      C0146      P067      27-05-2024         1      300.68
# ...

# %%
file_path = a
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    200 non-null    object
#  1   CustomerName  200 non-null    object
#  2   Region        200 non-null    object
#  3   SignupDate    200 non-null    object
# dtypes: object(4)
# memory usage: 6.4+ KB
# None

# %%
file_path = b
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    100 non-null    object
#  1   ProductName  100 non-null    object
#  2   Category     100 non-null    object
#  3   Price        100 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB
# None

# %%
file_path = c
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price            1000 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 54.8+ KB
# None

# %%
file_path = a
df = pd.read_csv(file_path)
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)

if null_values.any():
    print("\nThere are null values in the dataset.")
else:
    print("\nNo null values found in the dataset.")
# Out:
# Null values in each column:
# CustomerID      0
# CustomerName    0
# Region          0
# SignupDate      0
# dtype: int64
#
# No null values found in the dataset.

# %%
file_path = b
df = pd.read_csv(file_path)
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)

if null_values.any():
    print("\nThere are null values in the dataset.")
else:
    print("\nNo null values found in the dataset.")
# Out:
# Null values in each column:
# ProductID      0
# ProductName    0
# Category       0
# Price          0
# dtype: int64
#
# No null values found in the dataset.

# %%
file_path = c
df = pd.read_csv(file_path)
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)

if null_values.any():
    print("\nThere are null values in the dataset.")
else:
    print("\nNo null values found in the dataset.")
# Out:
# Null values in each column:
# TransactionID      0
# CustomerID         0
# ProductID          0
# TransactionDate    0
# Quantity           0
# TotalValue         0
# Price              0
# dtype: int64
#
# No null values found in the dataset.

# %%
file_path = a
df = pd.read_csv(file_path)
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
if duplicates > 0:
    print("\nDuplicate rows:")
    print(df[df.duplicated()])
else:
    print("\nNo duplicate rows found.")
# Out:
# Number of duplicate rows: 0
#
# No duplicate rows found.

# %%
file_path = b
df = pd.read_csv(file_path)
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
if duplicates > 0:
    print("\nDuplicate rows:")
    print(df[df.duplicated()])
else:
    print("\nNo duplicate rows found.")
# Out:
# Number of duplicate rows: 0
#
# No duplicate rows found.

# %%
file_path = c
df = pd.read_csv(file_path)
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
if duplicates > 0:
    print("\nDuplicate rows:")
    print(df[df.duplicated()])
else:
    print("\nNo duplicate rows found.")
# Out:
# Number of duplicate rows: 0
#
# No duplicate rows found.

# %%
def find_duplicates_in_csv(file_path, columns=None):
  df = pd.read_csv(file_path)
  if columns:
    duplicates = df[df.duplicated(subset=columns, keep=False)] 
  else:
    duplicates = df[df.duplicated(keep=False)] 
  return duplicates

file_path = a 
columns_to_check = ["CustomerID", "CustomerName","Region","SignupDate"] 

duplicate_rows = find_duplicates_in_csv(file_path, columns=columns_to_check)

if not duplicate_rows.empty:
  print("Duplicate rows found:")
  print(duplicate_rows)
else:
  print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
def find_duplicates_in_csv(file_path, columns=None):
  df = pd.read_csv(file_path)
  if columns:
    duplicates = df[df.duplicated(subset=columns, keep=False)] 
  else:
    duplicates = df[df.duplicated(keep=False)] 
  return duplicates

file_path = b
columns_to_check = ["ProductID", "ProductName","Category","Price"] 

duplicate_rows = find_duplicates_in_csv(file_path, columns=columns_to_check)

if not duplicate_rows.empty:
  print("Duplicate rows found:")
  print(duplicate_rows)
else:
  print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
def find_duplicates_in_csv(file_path, columns=None):
  df = pd.read_csv(file_path)
  if columns:
    duplicates = df[df.duplicated(subset=columns, keep=False)] 
  else:
    duplicates = df[df.duplicated(keep=False)] 
  return duplicates

file_path = c
columns_to_check = ["TransactionID","CustomerID","ProductID","TransactionDate","Quantity","TotalValue","Price"] 

duplicate_rows = find_duplicates_in_csv(file_path, columns=columns_to_check)

if not duplicate_rows.empty:
  print("Duplicate rows found:")
  print(duplicate_rows)
else:
  print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
def find_outliers_iqr_multiple_columns(df, columns):
  outliers_dict = {}
  for column in columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)].index.tolist()
    outliers_dict[column] = outliers
  return outliers_dict

# Example usage:
file_path = c
df = pd.read_csv(file_path)

columns_to_check = ["Quantity","TotalValue","Price"]
outliers = find_outliers_iqr_multiple_columns(df, columns_to_check)

for column, indices in outliers.items():
  if indices:
    print(f"Outliers found in '{column}':")
    print(df.loc[indices, [column]])  # Print only the outlier values for the specific column
  else:
    print(f"No outliers found in '{column}'.")
# Out:
# No outliers found in 'Quantity'.
# No outliers found in 'TotalValue'.
# No outliers found in 'Price'.

# %%
"""Mergeing the data of consumer and product to transcation dat based on 
ProductID and CustomerID"""
import pandas as pd
transactions = pd.read_csv(c)
customers = pd.read_csv(a)
merged_df = pd.merge(transactions, customers, on="CustomerID", how="left")
print(merged_df)
merged_df.to_csv("E:/DA_Projects/2/merged_data.csv", index=False)
# Out:
#     TransactionID CustomerID ProductID TransactionDate  Quantity  TotalValue  \
# 0          T00001      C0199      P067      25-08-2024         1      300.68
# 1          T00112      C0146      P067      27-05-2024         1      300.68
# 2          T00166      C0127      P067      25-04-2024         1      300.68
# 3          T00272      C0087      P067      26-03-2024         2      601.36
# 4          T00363      C0070      P067      21-03-2024         3      902.04
# ..            ...        ...       ...             ...       ...         ...
# 995        T00496      C0118      P037      24-10-2024         1      459.86
# 996        T00759      C0059      P037      04-06-2024         3     1379.58
# 997        T00922      C0018      P037      05-04-2024         4     1839.44
# 998        T00959      C0115      P037      29-09-2024         2      919.72
# 999        T00992      C0024      P037      21-04-2024         1      459.86
#
# ...

# %%
import pandas as pd
transactions = pd.read_csv("E:/DA_Projects/2/merged_data.csv")
customers = pd.read_csv(b)
merged_df = pd.merge(transactions, customers, on="ProductID", how="left")
print(merged_df)
merged_df.to_csv("E:/DA_Projects/2/merged_data.csv", index=False)
# Out:
#     TransactionID CustomerID ProductID TransactionDate  Quantity  TotalValue  \
# 0          T00001      C0199      P067      25-08-2024         1      300.68
# 1          T00112      C0146      P067      27-05-2024         1      300.68
# 2          T00166      C0127      P067      25-04-2024         1      300.68
# 3          T00272      C0087      P067      26-03-2024         2      601.36
# 4          T00363      C0070      P067      21-03-2024         3      902.04
# ..            ...        ...       ...             ...       ...         ...
# 995        T00496      C0118      P037      24-10-2024         1      459.86
# 996        T00759      C0059      P037      04-06-2024         3     1379.58
# 997        T00922      C0018      P037      05-04-2024         4     1839.44
# 998        T00959      C0115      P037      29-09-2024         2      919.72
# 999        T00992      C0024      P037      21-04-2024         1      459.86
#
# ...

# %%
d="E:/DA_Projects/2/merged_data.csv"

# %%
import pandas as pd
file_path = d
df = pd.read_csv(file_path)

print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price_x          1000 non-null   float64
#  7   CustomerName     1000 non-null   object
#  8   Region           1000 non-null   object
#  9   SignupDate       1000 non-null   object
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
#  12  Price_y          1000 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 101.7+ KB
# None

# %%
import pandas as pd

file_path = d
df = pd.read_csv(file_path)
print("Basic Info:")
print(df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price_x          1000 non-null   float64
#  7   CustomerName     1000 non-null   object
#  8   Region           1000 non-null   object
#  9   SignupDate       1000 non-null   object
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
#  12  Price_y          1000 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 101.7+ KB
# None

# %%
def analyze_column(file_path, column_name):
  try:
    df = pd.read_csv(file_path)
  except FileNotFoundError:
    print(f"Error: File not found: {file_path}")
    return None

  try:
    column_data = df[column_name]
  except KeyError:
    print(f"Error: Column '{column_name}' not found in the file.")
    return None
  column_data = column_data.dropna() 

  stats = {
      'count': len(column_data),
      'mean': column_data.mean(),
      'std': column_data.std(),
      'min': column_data.min(),
      '25%': column_data.quantile(0.25),
      '50%': column_data.median(),
      '75%': column_data.quantile(0.75),
      'max': column_data.max()
  }

  return stats
file_path = d  
column_name = 'Quantity' 

column_stats = analyze_column(file_path, column_name)

if column_stats:
  print(f"Statistical Analysis for '{column_name}':")
  for stat, value in column_stats.items():
    print(f"{stat}: {value}")
# Out:
# Statistical Analysis for 'Quantity':
# count: 1000
# mean: 2.537
# std: 1.117980715791143
# min: 1
# 25%: 2.0
# 50%: 3.0
# 75%: 4.0
# max: 4

# %%
import pandas as pd

def analyze_column(file_path, column_name):
  try:
    df = pd.read_csv(file_path)
  except FileNotFoundError:
    print(f"Error: File not found: {file_path}")
    return None

  try:
    column_data = df[column_name]
  except KeyError:
    print(f"Error: Column '{column_name}' not found in the file.")
    return None

  column_data = column_data.dropna() 

  stats = {
      'count': len(column_data),
      'mean': column_data.mean(),
      'std': column_data.std(),
      'min': column_data.min(),
      '25%': column_data.quantile(0.25),
      '50%': column_data.median(),
      '75%': column_data.quantile(0.75),
      'max': column_data.max()
  }

  return stats
file_path = d  
column_name = 'TotalValue' 
column_stats = analyze_column(file_path, column_name)

if column_stats:
  print(f"Statistical Analysis for '{column_name}':")
  for stat, value in column_stats.items():
    print(f"{stat}: {value}")
# Out:
# Statistical Analysis for 'TotalValue':
# count: 1000
# mean: 689.995559999999
# std: 493.14447754793144
# min: 16.08
# 25%: 295.29499999999996
# 50%: 588.88
# 75%: 1011.66
# max: 1991.04

# %%
import pandas as pd

def analyze_column(file_path, column_name):
  try:
    df = pd.read_csv(file_path)
  except FileNotFoundError:
    print(f"Error: File not found: {file_path}")
    return None

  try:
    column_data = df[column_name]
  except KeyError:
    print(f"Error: Column '{column_name}' not found in the file.")
    return None

  # Handle potential missing values
  column_data = column_data.dropna() 

  stats = {
      'count': len(column_data),
      'mean': column_data.mean(),
      'std': column_data.std(),
      'min': column_data.min(),
      '25%': column_data.quantile(0.25),
      '50%': column_data.median(),
      '75%': column_data.quantile(0.75),
      'max': column_data.max()
  }

  return stats
file_path = d 
column_name = 'Price_x'  

column_stats = analyze_column(file_path, column_name)

if column_stats:
  print(f"Statistical Analysis for '{column_name}':")
  for stat, value in column_stats.items():
    print(f"{stat}: {value}")
# Out:
# Statistical Analysis for 'Price_x':
# count: 1000
# mean: 272.5540699999993
# std: 140.73638962578207
# min: 16.08
# 25%: 147.95
# 50%: 299.93
# 75%: 404.4
# max: 497.76

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(d)
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
df['SignupDate'] = pd.to_datetime(df['SignupDate'])
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_13228\3631278880.py:5: UserWarning: Parsing '25-08-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
# C:\Users\mayan\AppData\Local\Temp\ipykernel_13228\3631278880.py:5: UserWarning: Parsing '27-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
# C:\Users\mayan\AppData\Local\Temp\ipykernel_13228\3631278880.py:5: UserWarning: Parsing '25-04-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
# ...

# %%
print("\nQuantity Analysis:")
print(df['Quantity'].describe())
plt.figure(figsize=(8, 4))
sns.histplot(df['Quantity'], bins=20)
plt.title("Distribution of Quantity")
plt.show()
# Out:
# Quantity Analysis:
# count    1000.000000
# mean        2.537000
# std         1.117981
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: Quantity, dtype: float64

# %%
print("\nPrice_x Analysis:")
price_x_stats = df['Price_x'].describe()  
print(price_x_stats)
plt.figure(figsize=(8, 4))
ax = sns.histplot(df['Price_x'], bins=20, color='skyblue', kde=True) 
plt.title("Distribution of Price")
plt.xlabel("Price_x")
plt.ylabel("Frequency")
mean_price = df['Price_x'].mean()
median_price = df['Price_x'].median()
ax.axvline(mean_price, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_price:.2f}')
ax.axvline(median_price, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_price:.2f}')
q1 = df['Price_x'].quantile(0.25)
q3 = df['Price_x'].quantile(0.75)
ax.axvline(q1, color='orange', linestyle='dashed', linewidth=1, label=f'Q1: {q1:.2f}')
ax.axvline(q3, color='purple', linestyle='dashed', linewidth=1, label=f'Q3: {q3:.2f}')
plt.legend() 
plt.tight_layout()
# Out:
# Price_x Analysis:
# count    1000.00000
# mean      272.55407
# std       140.73639
# min        16.08000
# 25%       147.95000
# 50%       299.93000
# 75%       404.40000
# max       497.76000
# Name: Price_x, dtype: float64

# %%
print("Expenditure Analysis:")
expenditure_stats = df['TotalValue'].describe()  
print(expenditure_stats)
plt.figure(figsize=(8, 4))
ax = sns.histplot(df['TotalValue'], bins=20, color='skyblue', kde=True) 
plt.title("Distribution of Expenditure")
plt.xlabel("Expenditure")
plt.ylabel("Frequency")
mean_expenditure = df['TotalValue'].mean()
median_expenditure = df['TotalValue'].median()
ax.axvline(mean_expenditure, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_expenditure:.2f}')
ax.axvline(median_expenditure, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_expenditure:.2f}')
q1 = df['TotalValue'].quantile(0.25)
q3 = df['TotalValue'].quantile(0.75)
ax.axvline(q1, color='orange', linestyle='dashed', linewidth=1, label=f'Q1: {q1:.2f}')
ax.axvline(q3, color='purple', linestyle='dashed', linewidth=1, label=f'Q3: {q3:.2f}')
plt.legend() 
plt.tight_layout()
# Out:
# Expenditure Analysis:
# count    1000.000000
# mean      689.995560
# std       493.144478
# min        16.080000
# 25%       295.295000
# 50%       588.880000
# 75%      1011.660000
# max      1991.040000
# Name: TotalValue, dtype: float64

# %%
print("\nRegion Analysis:")
region_counts = df['Region'].value_counts()
print(region_counts)

plt.figure(figsize=(8, 6))
plt.pie(region_counts, labels=region_counts.index, autopct='%1.1f%%', startangle=90) 
plt.title("Distribution of Transactions by Region (Pie Chart)")
plt.show()
# Out:
# Region Analysis:
# South America    304
# North America    244
# Europe           234
# Asia             218
# Name: Region, dtype: int64

# %%
region_sales = df.groupby('Region')['TotalValue'].sum()
print("Total Value of Sales by Category ($):")
print(region_sales)
plt.figure(figsize=(8, 6))  
plt.pie(region_sales, labels=region_sales.index, autopct='%1.1f%%') 
plt.title('Total Value of Sales by Region ($)')
plt.show()
# Out:
# Total Value of Sales by Category ($):
# Region
# Asia             152074.97
# Europe           166254.63
# North America    152313.40
# South America    219352.56
# Name: TotalValue, dtype: float64

# %%
category_colors = {"Electronics": "blue", "Clothing": "red", "Books": "green", "Home Decor": "orange"}
print("\nCategory Analysis:")
category_counts = df['Category'].value_counts()
print(category_counts)
plt.figure(figsize=(8, 6))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, 
        colors=[category_colors.get(cat, 'gray') for cat in category_counts.index])
plt.title("Distribution of Transactions by Category")
plt.show()
# Out:
# Category Analysis:
# Books          270
# Electronics    254
# Home Decor     248
# Clothing       228
# Name: Category, dtype: int64

# %%
category_sales = df.groupby('Category')['TotalValue'].sum()
print("Total Value of Sales by Category ($):")
print(category_sales)
plt.figure(figsize=(8, 6))  
plt.pie(category_sales, labels=category_sales.index, autopct='%1.1f%%', colors=[category_colors.get(cat, 'gray') for cat in category_sales.index]) 
plt.title('Total Value of Sales by Category ($)')
plt.show()
# Out:
# Total Value of Sales by Category ($):
# Category
# Books          192147.47
# Clothing       166170.66
# Electronics    180783.50
# Home Decor     150893.93
# Name: TotalValue, dtype: float64

# %%
daily_transactions = df.groupby(df['TransactionDate'].dt.date)['TransactionID'].count()
plt.figure(figsize=(12, 6))
plt.plot(daily_transactions.index, daily_transactions.values)
plt.xlabel('Date')
plt.ylabel('Number of Transactions')
plt.title('Daily Transactions')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(d) 
df['TransactionDate'] = pd.to_datetime(df['TransactionDate']) 
df['Month'] = df['TransactionDate'].dt.month 
monthly_transactions = df.groupby('Month')['TransactionID'].count()
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_7484\1608295149.py:5: UserWarning: Parsing '25-08-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
# C:\Users\mayan\AppData\Local\Temp\ipykernel_7484\1608295149.py:5: UserWarning: Parsing '27-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
# C:\Users\mayan\AppData\Local\Temp\ipykernel_7484\1608295149.py:5: UserWarning: Parsing '25-04-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
# ...

# %%
monthly_transactions_df = monthly_transactions.reset_index()
monthly_transactions_df.columns = ['Month', 'Transactions']

plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Month', y='Transactions', data=monthly_transactions_df)

plt.xlabel('Month')
plt.ylabel('Number of Transactions')
plt.title('Monthly Transaction Trends') 
plt.xticks(rotation=45) 
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
df['Quarter'] = df['TransactionDate'].dt.quarter
quarterly_transactions = df.groupby('Quarter')['TransactionID'].count()
quarterly_transactions_df = quarterly_transactions.reset_index()
quarterly_transactions_df.columns = ['Quarter', 'Transactions']
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Quarter', y='Transactions', data=quarterly_transactions_df)
plt.xlabel('Quarter')
plt.ylabel('Number of Transactions')
plt.title('Quarterly Transactions')
plt.xticks(rotation=45)
plt.tight_layout()
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points') # Better annotation placement
plt.show()

# %%
product_sales = df.groupby('ProductName')['TransactionID'].count().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='ProductName', data=df, order=product_sales.index, hue=None)
plt.xlabel('Product Name')
plt.ylabel('Number of Transactions')
plt.title('Sales by Product Name (Quantity)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()
product_value = df.groupby('ProductName')['TotalValue'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
product_value.plot(kind='bar')
plt.xlabel('Product Name')
plt.ylabel('Total Value of Sales')
plt.title('Total Value of Sales by Product Name')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
product_sales = df.groupby(['ProductName', 'Category'])['TransactionID'].count().unstack(fill_value=0)
ax = product_sales.plot(kind='bar', stacked=True, figsize=(12, 6), 
                        color=[category_colors.get(c, 'gray') for c in product_sales.columns])
plt.xlabel('Product Name')
plt.ylabel('Number of Transactions')
plt.title('Sales by Product Name')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    total_height = 0  
    for rect in ax.patches: 
        if rect.get_x() == x:
            total_height += rect.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', (x + width/2, total_height),  
                    ha='center', va='bottom', xytext=(0, 5), textcoords='offset points', fontsize=8) 
plt.show()
product_value = df.groupby(['ProductName', 'Category'])['TotalValue'].sum().unstack(fill_value=0)
product_value.plot(kind='bar', stacked=True, figsize=(12, 6), color=[category_colors.get(c, 'gray')
                                                                     for c in product_value.columns])
plt.xlabel('Product Name')
plt.ylabel('Total Value of Sales')
plt.title('Total Value of Sales by Product Name ')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
product_sales = df.groupby('ProductName')['TransactionID'].count().sort_values(ascending=False)
product_value = df.groupby('ProductName')['TotalValue'].sum().sort_values(ascending=False)
top_10_products_quantity = product_sales.head(10)
top_10_products_value = product_value.head(10)

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_10_products_quantity.index, y=top_10_products_quantity.values)  # Directly use top_10_data
plt.xlabel('Product Name')
plt.ylabel('Number of Transactions')
plt.title('Top 10 Products by Sales (Quantity)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_10_products_value.index, y=top_10_products_value.values)
plt.xlabel('Product Name')
plt.ylabel('Total Value of Sales')
plt.title('Top 10 Products by Total Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

# %%
least_10_products = product_sales.tail(10)

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=least_10_products.index, y=least_10_products.values)  # Directly use least_10 data
plt.xlabel('Product Name')
plt.ylabel('Number of Transactions')
plt.title('Least 10 Products by Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

product_value = df.groupby('ProductName')['TotalValue'].sum().sort_values(ascending=False)
least_10_value = product_value.tail(10)
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=least_10_value.index, y=least_10_value.values)
plt.xlabel('Product Name')
plt.ylabel('Total Value of Sales')
plt.title('Least 10 Products by Total Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

# %%
product_quantity = df.groupby(['ProductName', 'Category'])['Quantity'].sum().unstack(fill_value=0) 
category_colors = {"Electronics": "blue", "Clothing": "red", "Books": "green", "Home Decor": "orange"}

for category in product_quantity.columns:
    category_quantity = product_quantity[category].sort_values(ascending=False)  
    category_quantity = category_quantity[category_quantity > 0]

    if not category_quantity.empty:
        plt.figure(figsize=(12, 6))
        color = category_colors.get(category)
        if color is None:
            print(f"Warning: Color not defined for category '{category}'. Using default gray.")
            color = 'gray'
        ax = sns.barplot(x=category_quantity.index, y=category_quantity.values, color=color)
        plt.xlabel('Product Name')
        plt.ylabel('Total Quantity Sold')
        plt.title(f'Product Quantity Sold in {category}')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        for p in ax.patches:
            ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='center', xytext=(0, 5), textcoords='offset points')
        plt.show()

# %%
product_value = df.groupby(['ProductName', 'Category'])['TotalValue'].sum().unstack(fill_value=0)
for category in product_value.columns:
    category_value = product_value[category].sort_values(ascending=False)
    category_value = category_value[category_value > 0]

    if not category_value.empty: 
        plt.figure(figsize=(12, 6))
        color = category_colors.get(category) 
        if color is None:
            print(f"Warning: Color not defined for category '{category}'. Using default gray.")
            color = 'gray'

        ax = sns.barplot(x=category_value.index, y=category_value.values, color=color)  # Use color

        plt.xlabel('Product Name')
        plt.ylabel('Total Value of Sales')
        plt.title(f'Total Value of Sales by Product Name in {category} ')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()

        for p in ax.patches:
            ax.annotate(f'${p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='center', xytext=(0, 5), textcoords='offset points')

        plt.show()

# %%
region_category_sales = df.groupby(['Region', 'Category'])['TotalValue'].sum().unstack(fill_value=0)
for region in region_category_sales.index:
    region_data = region_category_sales.loc[region]
    plt.figure(figsize=(10, 6))  
    ax = sns.barplot(x=region_data.index, y=region_data.values, palette=category_colors)  # Use category colors
    plt.xlabel('Category')
    plt.ylabel('Total Value of Sales')
    plt.title(f'Sales by Category in {region}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

    for p in ax.patches:
        ax.annotate(f'${p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')
    total_value = region_data.sum()
    ax.text(0.95, 0.95, f"Total: ${total_value:.2f}",  # Position in top-right
            transform=ax.transAxes, ha='right', va='top', fontsize=10) # Use axes coordinates

    plt.show()

# %%
region_category_counts = df.groupby(['Region', 'Category'])['TransactionID'].count().unstack(fill_value=0)

for region in region_category_counts.index:
    region_data = region_category_counts.loc[region]

    plt.figure(figsize=(10, 6))
    ax = sns.countplot(x='Category', data=df[df['Region'] == region], order=region_data.index, palette=category_colors) # Using countplot
    plt.xlabel('Category')
    plt.ylabel('Number of Transactions')
    plt.title(f'Number of Transactions by Category in {region}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

    for p in ax.patches: # Annotations
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

    plt.show()

# %%
transactions_per_customer = df.groupby('CustomerID')['TransactionID'].count()
plt.figure(figsize=(10, 6))

bin_edges = range(0, transactions_per_customer.max() + 2)  # One extra bin edge
ax = sns.histplot(transactions_per_customer, bins=bin_edges, discrete=True, shrink=0.8, palette="viridis")  # discrete=True is important

plt.xlabel('Number of Transactions')
plt.ylabel('Number of Customers')
plt.title('Distribution of Transactions per Customer')

max_transactions = transactions_per_customer.max()
tick_positions = range(0, max_transactions + 1)
plt.xticks(tick_positions)

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2  
    y = p.get_height()
    ax.annotate(f'{int(y)}', (x, y),ha='center', va='bottom',
                xytext=(0, 5), textcoords='offset points') 
plt.show()

# %%
n=10
top_n_customers = transactions_per_customer.nlargest(n)

print(f"\nTop {n} Customers by Transactions:")
print(top_n_customers)

plt.figure(figsize=(10, 6))
ax = sns.barplot(x=top_n_customers.index, y=top_n_customers.values)
plt.xlabel('Customer ID')
plt.ylabel('Number of Transactions')
plt.title(f'Top {n} Customers by Number of Transactions')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()
# Out:
# Top 10 Customers by Transactions:
# CustomerID
# C0109    11
# C0156    11
# C0008    10
# C0065    10
# C0141    10
# C0175    10
# C0075     9
# C0084     9
# C0093     9
# C0147     9
# Name: TransactionID, dtype: int64

# %%
n = 10  
top_n_customers = transactions_per_customer.nlargest(n)

top_customers_with_regions = df[df['CustomerID'].isin(top_n_customers.index)][['CustomerID', 'Region']].drop_duplicates(subset='CustomerID')
top_n_customers = top_n_customers.reset_index()
top_n_customers_with_regions = pd.merge(top_n_customers, top_customers_with_regions, on='CustomerID')
print(top_n_customers_with_regions[['CustomerID', 'TransactionID', 'Region']].to_string(index=False))
# Out:
# CustomerID  TransactionID        Region
#      C0109             11 North America
#      C0156             11 North America
#      C0008             10 North America
#      C0065             10 North America
#      C0141             10        Europe
#      C0175             10          Asia
#      C0075              9        Europe
#      C0084              9          Asia
#      C0093              9          Asia
#      C0147              9 South America

# %%
customer_value = df.groupby('CustomerID')['TotalValue'].sum()
n = 10
top_n_customers_by_value = customer_value.nlargest(n)
top_n_customers_df = top_n_customers_by_value.reset_index()
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='CustomerID', y='TotalValue', data=top_n_customers_df)

plt.xlabel('Customer ID')
plt.ylabel('Total Value')
plt.title(f'Top {n} Customers by Total Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
for p in ax.patches:
    ax.annotate(f'${p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()
print(top_n_customers_df.to_string(index=False))
# Out:
# CustomerID  TotalValue
#      C0141    10673.87
#      C0054     8040.39
#      C0065     7663.70
#      C0156     7634.45
#      C0082     7572.91
#      C0188     7111.32
#      C0059     7073.28
#      C0028     6819.57
#      C0099     6715.72
#      C0165     6708.10

# %%
customer_value = df.groupby('CustomerID')['TotalValue'].sum()
n = 10
top_n_customers_by_value = customer_value.nlargest(n)
top_customers_with_info = df[df['CustomerID'].isin(top_n_customers_by_value.index)][['CustomerID', 'Region', 'CustomerName']].drop_duplicates(subset='CustomerID')
top_n_customers_by_value = top_n_customers_by_value.reset_index()
top_n_customers_with_info = pd.merge(top_n_customers_by_value, top_customers_with_info, on='CustomerID')

print("Top 10 Customers by Total Value:")
print(top_n_customers_with_info[['CustomerID', 'TotalValue', 'Region', 'CustomerName']].to_string(index=False))
# Out:
# Top 10 Customers by Total Value:
# CustomerID  TotalValue        Region         CustomerName
#      C0141    10673.87        Europe         Paul Parsons
#      C0054     8040.39          Asia         Bruce Rhodes
#      C0065     7663.70 North America         Gerald Hines
#      C0156     7634.45 North America        William Adams
#      C0082     7572.91 South America         Aimee Taylor
#      C0188     7111.32 South America            Anna Ball
#      C0059     7073.28 North America Mrs. Kimberly Wright
#      C0028     6819.57          Asia        Jennifer Pena
#      C0099     6715.72 South America         Rodney Eaton
#      C0165     6708.10 South America        Juan Mcdaniel

# %%
product_transactions = df.groupby('ProductName')['TransactionID'].count().nlargest(5)
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=product_transactions.index, y=product_transactions.values)
plt.xlabel('Product Name')
plt.ylabel('Number of Transactions')
plt.title('Top 5 Products by Number of Transactions')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

product_revenue = df.groupby('ProductName')['TotalValue'].sum().nlargest(5)
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=product_revenue.index, y=product_revenue.values)
plt.xlabel('Product Name')
plt.ylabel('Total Revenue')
plt.title('Top 5 Products by Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'${p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

# %%
product_quantity = df.groupby('ProductName')['Quantity'].sum()
top_10_products_quantity = product_quantity.nlargest(10)
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
ax = sns.barplot(x=top_10_products_quantity.index, y=top_10_products_quantity.values)
plt.xlabel('Product Name')
plt.ylabel('Total Quantity Sold')
plt.title('Top 10 Products by Quantity Sold')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
top_products_with_regions = df[df['ProductName'].isin(top_10_products_quantity.index)][['ProductName', 'Region']].drop_duplicates(subset='ProductName')
top_10_products_with_regions = pd.merge(top_10_products_quantity.to_frame(), top_products_with_regions, on='ProductName', how='left') #how='left' keeps all the top 10 even if region is missing
print("Top 10 Products by Quantity Sold and their Region")
print(top_10_products_with_regions.to_string(index=False))
# Out:
# Top 10 Products by Quantity Sold and their Region
#           ProductName  Quantity        Region
# ActiveWear Smartwatch       100          Asia
#  SoundWave Headphones        97 North America
#   HomeSense Desk Lamp        81 South America
#        ActiveWear Rug        79        Europe
#    SoundWave Cookbook        78 South America
#     ActiveWear Jacket        76          Asia
#   BookWorld Biography        71 North America
#       TechPro T-Shirt        66 North America
#   SoundWave Desk Lamp        64          Asia
#      TechPro Textbook        62 South America

# %%
df['SignupDate'] = pd.to_datetime(df['SignupDate'])
daily_signups = df.resample('D', on='SignupDate')['CustomerID'].nunique()
# Create the bar chart for daily signups
plt.figure(figsize=(12, 6))
plt.bar(daily_signups.index, daily_signups.values)
plt.xlabel("Date")
plt.ylabel("Number of New Customers")
plt.title("Daily Customer Signups")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
average_signups = daily_signups.mean()
print("average signups Per Day :",average_signups)
# Out:
# average signups Per Day : 0.18563432835820895

# %%
df['SignupDate'] = pd.to_datetime(df['SignupDate'])
daily_signups = df.groupby('SignupDate')['CustomerID'].nunique()
top_20_signups = daily_signups.sort_values(ascending=False).head(20)
print("Top 20 Signups by Date:")
print(top_20_signups.to_string(header=False))
# Out:
# Top 20 Signups by Date:
# 2022-04-16    3
# 2024-11-11    3
# 2024-02-20    2
# 2024-07-10    2
# 2022-05-13    2
# 2024-09-17    2
# 2024-02-05    2
# 2024-01-30    2
# 2023-01-13    2
# 2024-04-07    2
# 2023-03-16    2
# 2022-03-14    2
# 2023-10-17    2
# 2024-11-13    2
# 2022-06-18    2
# 2024-04-11    2
# 2022-02-13    2
# 2024-11-22    2
# 2024-09-21    2
# 2024-02-07    1

# %%
weekly_signups = df.resample('W', on='SignupDate')['CustomerID'].nunique()
# Create the bar chart for weekly signups
plt.figure(figsize=(12, 6))
plt.bar(weekly_signups.index, weekly_signups.values)
plt.xlabel("Week")
plt.ylabel("Number of New Customers")
plt.title("Weekly Customer Signups")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
monthly_signups = df.resample('M', on='SignupDate')['CustomerID'].nunique()

# Create the bar chart for monthly signups
plt.figure(figsize=(12, 6))
plt.bar(monthly_signups.index, monthly_signups.values)
plt.xlabel("Month")
plt.ylabel("Number of New Customers")
plt.title("Monthly Customer Signups")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['SignupDate'] = pd.to_datetime(df['SignupDate'])
monthly_signups = df.resample('M', on='SignupDate')['CustomerID'].nunique()
top_20_signups = monthly_signups.sort_values(ascending=False).head(20)
top_20_signups.index = top_20_signups.index.strftime('%Y-%m') 
montly_avg_signups = monthly_signups.mean()
print("Average signups Per Monthy :",montly_avg_signups)
print("Top 20 Signups by Month:")
print(top_20_signups.to_string(header=False))
# Out:
# Average signups Per Monthy : 5.527777777777778
# Top 20 Signups by Month:
# 2024-09    11
# 2024-11    11
# 2024-04    10
# 2024-01     9
# 2024-02     8
# 2023-03     8
# 2022-05     8
# 2022-03     8
# 2022-04     8
# 2022-12     7
# 2022-02     7
# 2023-10     6
# 2022-09     6
# 2023-02     6
# 2024-05     6
# 2023-04     6
# 2024-07     6
# 2023-12     5
# 2023-11     5
# 2024-10     5

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
df_sorted = df.sort_values(['CustomerID', 'TransactionDate'])
df_sorted['Prev_TransactionDate'] = df_sorted.groupby('CustomerID')['TransactionDate'].shift(1)
df_sorted['Days_Since_Last_Purchase'] = (df_sorted['TransactionDate'] - df_sorted['Prev_TransactionDate']).dt.days
df_filtered = df_sorted[df_sorted['Days_Since_Last_Purchase'].notna()]
plt.figure(figsize=(10, 6))
plt.hist(df_filtered['Days_Since_Last_Purchase'], bins=30, color='blue', alpha=0.7)
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Number of Customers')
plt.title('Distribution of Days Since Last Purchase')
plt.show()

plt.figure(figsize=(8, 6))
plt.boxplot(df_filtered['Days_Since_Last_Purchase'])
plt.ylabel('Days Since Last Purchase')
plt.title('Box Plot of Days Since Last Purchase')
plt.show()

# %%
print("Key Points from the Box Plot:")
stats = df_filtered['Days_Since_Last_Purchase'].describe()
print("Median (50th percentile):", stats['50%'])
print("25th percentile:", stats['25%'])
print("75th percentile:", stats['75%'])
print("Interquartile Range (IQR):", stats['75%'] - stats['25%'])
upper_whisker = stats['75%'] + 1.5 * (stats['75%'] - stats['25%'])
outliers = df_filtered[df_filtered['Days_Since_Last_Purchase'] > upper_whisker]
if len(outliers) > 0:
  print("Number of outliers:", len(outliers))
else:
  print("No outliers detected.")
print("Skew:", df_filtered['Days_Since_Last_Purchase'].skew())
# Out:
# Key Points from the Box Plot:
# Median (50th percentile): 40.0
# 25th percentile: 17.0
# 75th percentile: 79.0
# Interquartile Range (IQR): 62.0
# Number of outliers: 32
# Skew: 1.5324214809702543
